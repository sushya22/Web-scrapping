# %%
from flask import Flask,request,jsonify,render_template
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url="https://www.flipkart.com/search?q="+"wheat"

# %%
uclient=uReq(flipkart_url)

# %%
flipkartpage=uclient.read()

# %%
uclient.close()

# %%
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.8f4f44.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
len(flipkartpage)
# Out:
# 181565

# %%
flipkarthtml=bs(flipkartpage,'html.parser')

# %%
flipkarthtml
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkartitems=flipkarthtml.findAll("div",{"class":"_4ddWXP"})

# %%
len(flipkartitems)
# Out:
# 40

# %%
item=flipkartitems[1]

# %%
product_url=item.a['href']

# %%
product_url="https://www.flipkart.com"+product_url

# %%
product_url
# Out:
# 'https://www.flipkart.com/minimall-super-market-organics-superior-lokwan-wheat-loose-1-kg-whole/p/itmcc7f127a88ccc?pid=GNMG5B7T9ZYYYP6M&lid=LSTGNMG5B7T9ZYYYP6MPLGIMB&marketplace=FLIPKART&q=wheat&store=eat&srno=s_1_2&otracker=search&fm=organic&iid=daf79d9c-bd97-47c7-b651-43386166896a.GNMG5B7T9ZYYYP6M.SEARCH&ppt=None&ppn=None&ssid=om4w9d2afk0000001681118738234&qH=d29db4ac8712f5bd'

# %%
product_name=item.find_all('a')[1].text

# %%
product_quantity=item.find_all('div')[5].text

# %%
product_quantity
# Out:
# '1 kg'

# %%
item.find_all('div',{"class":"_30jeq3"})[0].text
# Out:
# '₹199'

# %%
product_name
# Out:
# 'MINIMALL SUPER MARKET Organics Superior Lokwan Wheat Lo...'

# %%
item.find_all('div')[6]
# Out:
# <div class="gUuXy- _2D5lwg"><span class="_1lRcqv" id="productRating_LSTGNMG5B7T9ZYYYP6MPLGIMB_GNMG5B7T9ZYYYP6M_"><div class="_3LWZlK">3.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ">(3)</span></div>

# %%
item.find_all('div',{"class":"_3Djpdu"})
# Out:
# [<div class="_3Djpdu">1 kg</div>]

# %%
item.find_all('div')
# Out:
# [<div><div><div class="CXW8mj _21_khk" style="height:230px;width:230px"><img alt="MINIMALL SUPER MARKET Organics Superior Lokwan Wheat Loose 1 Kg Whole Wheat" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/612/612/krjjde80/grain-millet/f/p/s/1-organics-superior-lokwan-wheat-loose-1-kg-whole-wheat-minimall-original-imag5b7tbxhknpj6.jpeg?q=70"/></div></div></div>,
#  <div><div class="CXW8mj _21_khk" style="height:230px;width:230px"><img alt="MINIMALL SUPER MARKET Organics Superior Lokwan Wheat Loose 1 Kg Whole Wheat" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/612/612/krjjde80/grain-millet/f/p/s/1-organics-superior-lokwan-wheat-loose-1-kg-whole-wheat-minimall-original-imag5b7tbxhknpj6.jpeg?q=70"/></div></div>,
# ...

# %%
item.find_all('div')[8]
# Out:
# <div class="_32g5_j"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div>

# %%
result=[]


for item in flipkartitems[0:10]:
    a_elements=item.find_all('a')
    div_elements=item.find_all('div')
    item_weight=item.find_all('div',{"class":"_3Djpdu"})
    #print(item_weight[0].text)
    weight = (int(item_weight[0].text.split()[0])/1000) if item_weight[0].text.split()[1]=='g' else item_weight[0].text.split()[0]
    #print(weight)
    #print(item_weight[0].text.split()[0])
    d={
        "product_name":item.find_all('a')[1].text,
        #"product_quantity":item.find_all('div')[5].text,
        #"product_price":str(float(item.find_all('div',{"class":"_30jeq3"})[0].text[1:].replace(',',''))/float(weight))+" Per kg",
        
        "product_price":item.find_all('div',{"class":"_30jeq3"})[0].text,
        "product_weight":item_weight[0].text,
        "product_order":"https://www.flipkart.com"+item.a['href']
    }
    
    result.append(d)

# %%
result
# Out:
# [{'product_name': 'PRODUCER PREMIUM 1st GRADE SHARBATI WHOLE WHEAT, 1kg Wh...',
#   'product_price': '₹199',
#   'product_weight': '1 kg',
#   'product_order': 'https://www.flipkart.com/producer-premium-1st-grade-sharbati-whole-wheat-1kg-wheat/p/itmbdee1b5b56617?pid=GNMG39XRZHX84PV7&lid=LSTGNMG39XRZHX84PV76IHIRZ&marketplace=FLIPKART&q=wheat&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=daf79d9c-bd97-47c7-b651-43386166896a.GNMG39XRZHX84PV7.SEARCH&ppt=None&ppn=None&ssid=om4w9d2afk0000001681118738234&qH=d29db4ac8712f5bd'},
#  {'product_name': 'MINIMALL SUPER MARKET Organics Superior Lokwan Wheat Lo...',
#   'product_price': '₹199',
#   'product_weight': '1 kg',
# ...

# %%
for i in result:
    print("produce_name",i['product_name'])
    #print("product_quantity",i["product_quantity"])
    #print("product_rating",i['product_price'])
    #print("product_order",i['product_order'])
    print("product_price",i['product_price'])
    print("product_weight",i['product_weight'])
    print("product_order",i['product_order'])
    print()
    print()
    print()
# Out:
# produce_name PRODUCER PREMIUM 1st GRADE SHARBATI WHOLE WHEAT, 1kg Wh...
# product_price ₹199
# product_weight 1 kg
# product_order https://www.flipkart.com/producer-premium-1st-grade-sharbati-whole-wheat-1kg-wheat/p/itmbdee1b5b56617?pid=GNMG39XRZHX84PV7&lid=LSTGNMG39XRZHX84PV76IHIRZ&marketplace=FLIPKART&q=wheat&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=daf79d9c-bd97-47c7-b651-43386166896a.GNMG39XRZHX84PV7.SEARCH&ppt=None&ppn=None&ssid=om4w9d2afk0000001681118738234&qH=d29db4ac8712f5bd
#
#
#
# produce_name MINIMALL SUPER MARKET Organics Superior Lokwan Wheat Lo...
# product_price ₹199
# product_weight 1 kg
# ...

# %%
len(a_elements)
# Out:
# 3

# %%
sorted(result,key=func)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7144\3537383898.py in <module>
# ----> 1 sorted(result,key=func)
#
# NameError: name 'func' is not defined
