# %%
from flask import Flask,request,jsonify,render_template
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url="https://www.flipkart.com/search?q="+"idlyrava"

# %%
uclient=uReq(flipkart_url)

# %%
flipkartpage=uclient.read()

# %%
uclient.close()

# %%
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
len(flipkartpage)
# Out:
# 175750

# %%
flipkarthtml=bs(flipkartpage,'html.parser')

# %%
flipkarthtml
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkartitems=flipkarthtml.findAll("div",{"class":"_4ddWXP"})

# %%
len(flipkartitems)
# Out:
# 40

# %%
item=flipkartitems[17]

# %%
product_url=item.a['href']

# %%
product_url="https://www.flipkart.com"+product_url

# %%
product_url
# Out:
# 'https://www.flipkart.com/sri-lalitha-premium-idly-rava-3kg/p/itm7bb3e63903ff9?pid=FLRGFKBWGFES9PC9&lid=LSTFLRGFKBWGFES9PC9XT8ZWC&marketplace=FLIPKART&q=idlyrava&store=eat&srno=s_1_18&otracker=search&fm=organic&iid=6350bd7a-cf7d-484f-ac5c-8f91efa21649.FLRGFKBWGFES9PC9.SEARCH&ppt=None&ppn=None&ssid=wwb0phxyqo0000001674890579937&qH=73b66096b36bdb0d'

# %%
product_name=item.find_all('a')[1].text

# %%
product_quantity=item.find_all('div')[5].text

# %%
product_quantity
# Out:
# '3 kg, Pack of 3'

# %%
product_name
# Out:
# 'SRI LALITHA PREMIUM IDLY RAVA 3KG'

# %%
item.find_all('div')
# Out:
# [<div><div><div class="CXW8mj _21_khk" style="height:230px;width:230px"><img alt="SRI LALITHA PREMIUM IDLY RAVA 3KG" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/612/612/l4pxk7k0/flour/x/v/y/2-premium-idly-rava-2-kg-2-rava-sri-lalitha-original-imagfkbremhyvfvb.jpeg?q=70"/></div></div></div>,
#  <div><div class="CXW8mj _21_khk" style="height:230px;width:230px"><img alt="SRI LALITHA PREMIUM IDLY RAVA 3KG" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/612/612/l4pxk7k0/flour/x/v/y/2-premium-idly-rava-2-kg-2-rava-sri-lalitha-original-imagfkbremhyvfvb.jpeg?q=70"/></div></div>,
#  <div class="CXW8mj _21_khk" style="height:230px;width:230px"><img alt="SRI LALITHA PREMIUM IDLY RAVA 3KG" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/612/612/l4pxk7k0/flour/x/v/y/2-premium-idly-rava-2-kg-2-rava-sri-lalitha-original-imagfkbremhyvfvb.jpeg?q=70"/></div>,
# ...

# %%
item.find_all('div')[7].text
# Out:
# '4.5'

# %%
result=[]


for item in flipkartitems[0:10]:
    a_elements=item.find_all('a')
    div_elements=item.find_all('div')
    d={
        "product_name":item.find_all('a')[1].text,
        "product_quantity":item.find_all('div')[5].text,
        "product_rating":item.find_all('div')[7].text,
        "product_order":"https://www.flipkart.com"+item.a['href']
    }
    
    result.append(d)

# %%
result
# Out:
# [{'product_name': 'MTR Rava Idli Mix 1 kg',
#   'product_quantity': '4.4(216)',
#   'product_rating': '₹280₹3099% off',
#   'product_order': 'https://www.flipkart.com/mtr-rava-idli-mix-1-kg/p/itm851d023c415a8?pid=RYMFWKRZZHGJTTUU&lid=LSTRYMFWKRZZHGJTTUULEXW9J&marketplace=FLIPKART&q=idlyrava&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=6350bd7a-cf7d-484f-ac5c-8f91efa21649.RYMFWKRZZHGJTTUU.SEARCH&ppt=None&ppn=None&ssid=wwb0phxyqo0000001674890579937&qH=73b66096b36bdb0d'},
#  {'product_name': 'Maayka - Ek Atoot Rishta Plain Dosa & Rava Idli Mix 200...',
#   'product_quantity': 'Pack of 2',
#   'product_rating': '4',
# ...

# %%
for i in result:
    print("name",i['product_name'])
    print("product_quantity",i["product_quantity"])
    print("product_rating",i['product_rating'])
    print("product_order",i['product_order'])
    print()
    print()
    print()
# Out:
# name MTR Rava Idli Mix 1 kg
# product_quantity 4.4(216)
# product_rating ₹280₹3099% off
# product_order https://www.flipkart.com/mtr-rava-idli-mix-1-kg/p/itm851d023c415a8?pid=RYMFWKRZZHGJTTUU&lid=LSTRYMFWKRZZHGJTTUULEXW9J&marketplace=FLIPKART&q=idlyrava&store=eat&srno=s_1_1&otracker=search&fm=organic&iid=6350bd7a-cf7d-484f-ac5c-8f91efa21649.RYMFWKRZZHGJTTUU.SEARCH&ppt=None&ppn=None&ssid=wwb0phxyqo0000001674890579937&qH=73b66096b36bdb0d
#
#
#
# name Maayka - Ek Atoot Rishta Plain Dosa & Rava Idli Mix 200...
# product_quantity Pack of 2
# product_rating 4
# product_order https://www.flipkart.com/maayka-ek-atoot-rishta-plain-dosa-rava-idli-mix-200-gm-400-g/p/itm4e2ca6fce5f61?pid=RYMG4F9WRHHFUSAH&lid=LSTRYMG4F9WRHHFUSAHKI95PO&marketplace=FLIPKART&q=idlyrava&store=eat&srno=s_1_2&otracker=search&fm=organic&iid=6350bd7a-cf7d-484f-ac5c-8f91efa21649.RYMG4F9WRHHFUSAH.SEARCH&ppt=None&ppn=None&ssid=wwb0phxyqo0000001674890579937&qH=73b66096b36bdb0d
#
#
#
# ...

# %%
len(a_elements)
# Out:
# 3
